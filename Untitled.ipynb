# %%
pip install streamlit
# Out:
# ...
#   Using cached streamlit-1.3.0-py2.py3-none-any.whl (9.2 MB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#      |████████████████████████████████| 180 kB 4.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.3 MB 2.5 MB/s eta 0:00:01
# ...
#   Using cached Pympler-1.0-py3-none-any.whl (164 kB)
# ...
#      |████████████████████████████████| 1.0 MB 2.3 MB/s eta 0:00:01
# ...
#   Using cached blinker-1.4.tar.gz (111 kB)
# ...
#      |████████████████████████████████| 19.1 MB 2.1 MB/s eta 0:00:01
# ...
#   Using cached validators-0.18.2-py3-none-any.whl (19 kB)
# ...
#   Using cached altair-4.1.0-py3-none-any.whl (727 kB)
# ...
#      |████████████████████████████████| 63 kB 2.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 339 kB 2.5 MB/s eta 0:00:01
# ...
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13451 sha256=166bc5afac4bb90d9ef3536616dd4aead050afbec40c45abfb949efb2f95742c
# ...

# %%
pip install streamlit-webrtc
# Out:
# ...
#   Using cached streamlit_webrtc-0.32.0-py3-none-any.whl (961 kB)
# ...
#      |████████████████████████████████| 1.2 MB 5.0 MB/s eta 0:00:01
# ...
#   Using cached pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# ...
#      |████████████████████████████████| 21.5 MB 2.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 52 kB 1.3 MB/s  eta 0:00:01
# ...
#   Using cached aioice-0.7.5-py3-none-any.whl (23 kB)
# ...
#   Using cached dnspython-2.1.0-py3-none-any.whl (241 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 45.9 MB 340 kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
streamlit run index.py
# Out:
#   File "<ipython-input-4-04bf1c70a57d>", line 1
#     streamlit run index.py
#               ^
# SyntaxError: invalid syntax
